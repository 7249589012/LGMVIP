# %% [markdown]
# <a href="https://colab.research.google.com/github/7249589012/LGMVIP/blob/main/LGMVIP_TASK2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Name: Suvarna Shalik Wagh
# 2. Class: B. Tech
# 3. College: SVKM-IOT

# %% [markdown]
# # Image to pencil sketch using python

# %% [markdown]
# **Step 1. Modules**
# 1. Using the OpenCV functions and matplotlib module to plot the images.

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# **Step 2. Loading & Plotting Original Image**
# 1. imread function which takes the path of the file.
# 2. changing the color code of the image to RGB to get the original colors and plot the image using the imshow function.

# %%
import cv2
img = cv2.imread("/content/SW_PASS.jpg")
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8,8))
plt.imshow(img)
plt.axis("off")
plt.title("Original")
plt.show()

# %% [markdown]
# **3. Image to GrayScale**
# 1. To decrease the complexity of the image lets convert the image to a grayscale image with the help of the cvtColor function.

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(8,8))
plt.imshow(img_gray,cmap="gray")
plt.axis("off")
plt.title("GrayScale Image")
plt.show()

# %% [markdown]
# **Step. 4 Inverting it from gray scale**

# %%
img_invert = cv2.bitwise_not(img_gray)
plt.figure(figsize=(8,8))
plt.imshow(img_invert,cmap="gray")
plt.axis("off")
plt.title("Inverted Image")
plt.show()

# %% [markdown]
# **Step 5. Smoothning**

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)
plt.figure(figsize=(8,8))
plt.imshow(img_smoothing,cmap="gray")
plt.axis("off")
plt.title("Smoothen")
plt.show()

# %% [markdown]
# **Step 6.images to pencil sketches**

# %%
final = cv2.divide(img_gray, 255 - img_smoothing, scale=255)
plt.figure(figsize=(8,8))
plt.imshow(final,cmap="gray")
plt.axis("off")
plt.title("Final Sketch")
plt.show()

# %%
plt.figure(figsize=(25,25))
plt.subplot(1,5,1)
plt.imshow(img)
plt.axis("off")
plt.title("Original")
plt.subplot(1,5,2)
plt.imshow(img_gray,cmap="gray")
plt.axis("off")
plt.title("GrayScale")
plt.subplot(1,5,3)
plt.imshow(img_invert,cmap="gray")
plt.axis("off")
plt.title("Inverted")
plt.subplot(1,5,4)
plt.imshow(img_smoothing,cmap="gray")
plt.axis("off")
plt.title("Smoothen")
plt.subplot(1,5,5)
plt.imshow(final,cmap="gray")
plt.axis("off")
plt.title("Final Sketch")
plt.show()

# %% [markdown]
# Final output figure number 4 shows the sketch of given original image.
